# %%
from ofxparse import OfxParser
from codecs import open

with open('/home/paulo/Downloads/2023-02.ofx', encoding='latin-1') as fofx:
    ofx = OfxParser.parse(fofx)

print(ofx.account.institution.organization)

for transaction in ofx.account.statement.transactions:
    print('----------------------------------')
    print('Payee', transaction.payee)
    print('Type', transaction.type)
    print('Date', transaction.date)
    print('User date', transaction.user_date)
    print('Amount', transaction.amount)
    print('Id', transaction.id)
    print('Memo', transaction.memo)
    print('Sic', transaction.sic)
    print('Mcc', transaction.mcc)
    print('Checksum', transaction.checknum)   
    print('----------------------------------')
# Out:
# Banco do Brasil
# ----------------------------------
# Payee
# Type other
# Date 2023-02-01 15:00:00
# User date None
# Amount -111.10
# Id 202302011111100
# Memo Compra com Cartão - 01/02 22:47 CONFEITARIA VERA CRU
# Sic None
# Mcc
# Checksum 000000355713
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-01 15:00:00
# User date None
# Amount -237.95
# Id 202302011237950
# Memo Pagto Energia Elétrica - ELEKTRO ELETRICIDADE E SE
# Sic None
# Mcc
# Checksum 000000048081
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-02 15:00:00
# User date None
# Amount -18.00
# Id 20230202118000
# Memo Compra com Cartão - 02/02 19:11 NATURAL DA TERRA TAT
# Sic None
# Mcc
# Checksum 000000809084
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-06 15:00:00
# User date None
# Amount 640.00
# Id 202302060640000
# Memo TED-Crédito em Conta - 633 0001     8488032803 ROSEMARY BOLAN
# Sic None
# Mcc
# Checksum 000033514655
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-06 15:00:00
# User date None
# Amount 10294.36
# Id 20230206010294360
# Memo TED-Crédito em Conta - 341 0525 54537337000161 INSTITUTO DE M
# Sic None
# Mcc
# Checksum 000267001527
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-06 15:00:00
# User date None
# Amount -1000.00
# Id 2023020611000000
# Memo Transferência enviada - 05/02 13:30 TELMA LAVINAS BARBOSA
# Sic None
# Mcc
# Checksum 859000131820
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-08 15:00:00
# User date None
# Amount -46.60
# Id 20230208146600
# Memo Compra com Cartão - 08/02 17:31 SHOPPING METRO EXPAN
# Sic None
# Mcc
# Checksum 000000223769
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-08 15:00:00
# User date None
# Amount -7.00
# Id 2023020817000
# Memo Compra com Cartão - 08/02 17:47 SHOPPING METRO EXPAN
# Sic None
# Mcc
# Checksum 000000236460
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-09 15:00:00
# User date None
# Amount -58.00
# Id 20230209158000
# Memo Compra com Cartão - 09/02 18:12 STUDIO FREEDOM HAIR
# Sic None
# Mcc
# Checksum 000000782908
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-10 15:00:00
# User date None
# Amount 950.00
# Id 202302100950000
# Memo Pix - Recebido - 10/02 22:56 00000248407694 Érika Olive
# Sic None
# Mcc
# Checksum 002793229977
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-13 15:00:00
# User date None
# Amount -429.06
# Id 202302131429060
# Memo Compra com Cartão - 11/02 19:11 CONFEITARIA VERA CRU
# Sic None
# Mcc
# Checksum 000000185171
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-14 15:00:00
# User date None
# Amount -74.00
# Id 20230214174000
# Memo Compra com Cartão - 14/02 20:48 CONFEITARIA VERA CRU
# Sic None
# Mcc
# Checksum 000000661658
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-16 15:00:00
# User date None
# Amount -126.50
# Id 202302161126500
# Memo Compra com Cartão - 16/02 18:36 LANCHONETE ACOPIARA
# Sic None
# Mcc
# Checksum 000000721858
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-22 15:00:00
# User date None
# Amount -83.20
# Id 20230222183200
# Memo Compra com Cartão - 21/02 21:13 CONFEITARIA VERA CRU
# Sic None
# Mcc
# Checksum 000000327952
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-22 15:00:00
# User date None
# Amount -100.00
# Id 202302221100000
# Memo Compra com Cartão - 19/02 16:00 PAO DE ACUCAR-1289
# Sic None
# Mcc
# Checksum 000000365417
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-24 15:00:00
# User date None
# Amount -63.20
# Id 20230224163200
# Memo Compra com Cartão - 24/02 21:21 CONFEITARIA VERA CRU
# Sic None
# Mcc
# Checksum 000000841924
# ----------------------------------
# ----------------------------------
# Payee
# Type other
# Date 2023-02-28 15:00:00
# User date None
# Amount -10000.00
# Id 20230228110000000
# Memo Transferência enviada - 28/02 14:39 TELMA LAVINAS BARBOSA
# Sic None
# Mcc
# Checksum 859000131820
# ----------------------------------
